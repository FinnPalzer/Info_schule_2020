# %%
def bruch1(zähler,nenner):
    ergebnis = zähler/nenner
    return ergebnis

def bruch2(zähler,nenner):
    ergebnis = zähler/nenner
    print(ergebnis)

# %%
x = bruch1(2,4)

# %%
x
# Out:
# 0.5

# %%
type(x)
# Out:
# float

# %%
y = bruch2(2,4)
# Out:
# 0.5

# %%
y

# %%
type(y)
# Out:
# NoneType
