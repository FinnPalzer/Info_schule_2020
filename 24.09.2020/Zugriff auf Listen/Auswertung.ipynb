# %%
adressen = ['a@gmx.de','b@hotmail.de','c@web.de','felo@wichtig.de','infomachtspaß@nicht.de']

# %%
adressen
# Out:
# ['a@gmx.de',
#  'b@hotmail.de',
#  'c@web.de',
#  'felo@wichtig.de',
#  'infomachtspaß@nicht.de']

# %%
adressen[0]
# Out:
# 'a@gmx.de'

# %%
adressen[1]
# Out:
# 'b@hotmail.de'

# %%
adressen[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\Sinus\OneDrive\Dokumente\Info\Phyton\24.09.2020\Zugriff auf Listen.py in <module>
# ----> 1 adressen[6]
#
# IndexError: list index out of range

# %%
adressen[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\Sinus\OneDrive\Dokumente\Info\Phyton\24.09.2020\Zugriff auf Listen.py in <module>
# ----> 1 adressen[7]
#
# IndexError: list index out of range

# %%
len(adressen)
# Out:
# 5

# %%
len(['a','b','c'])
# Out:
# 3

# %%
adressen[-1]
# Out:
# 'infomachtspaß@nicht.de'

# %%
adressen[-3]
# Out:
# 'c@web.de'

# %%
adressen[1] = 'h@nochnichtda.juhuu'

# %%
adressen[3] = 'auch@nochnichtda.deam'

# %%
adressen
# Out:
# ['a@gmx.de',
#  'h@nochnichtda.juhuu',
#  'c@web.de',
#  'auch@nochnichtda.deam',
#  'infomachtspaß@nicht.de']

# %%
adressen[2] = gmx.de
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Sinus\OneDrive\Dokumente\Info\Phyton\24.09.2020\Zugriff auf Listen.py in <module>
# ----> 1 adressen[2] = gmx.de
#
# NameError: name 'gmx' is not defined
