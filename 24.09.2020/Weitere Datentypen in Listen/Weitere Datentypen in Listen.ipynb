# %%
l = [1,12,21,31,37,46]

# %%
l = ['Lukas Podolski',14]

# %%
l = ['Max', 'Mustermann', [25, 2, 1995], ['Zweibrücken', 'Deutschland']]

# %%
l = []

# %%
l = ['Max', 'Mustermann', [25,2,1995], ['Zweibrücken', 'Deutschland']]

# %%
l[2]
# Out:
# [25, 2, 1995]

# %%
l[3][1]
# Out:
# 'Deutschland'

# %%
#kleines "m" ausgeben:
l[1][6]
# Out:
# 'm'

# %%
# "ü" in Zweibrücken
l[3][0][6]
# Out:
# 'ü'
