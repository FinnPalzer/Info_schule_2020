# %%
adressen = ['a@gmx.de','b@hotmail.de','c@web.de','felo@wichtig.de','infomachtspaß@nicht.de']

# %%
adressen[0:2]
# Out:
# ['a@gmx.de', 'b@hotmail.de']

# %%
adressen[2:5]
# Out:
# ['c@web.de', 'felo@wichtig.de', 'infomachtspaß@nicht.de']

# %%
adressen[1:4]
# Out:
# ['b@hotmail.de', 'c@web.de', 'felo@wichtig.de']

# %%
adressen[3:3]
# Out:
# []

# %%
adressen[3:8]
# Out:
# ['felo@wichtig.de', 'infomachtspaß@nicht.de']

# %%
adressen[0:len(adressen)]
# Out:
# ['a@gmx.de',
#  'b@hotmail.de',
#  'c@web.de',
#  'felo@wichtig.de',
#  'infomachtspaß@nicht.de']

# %%
adressen[2:]
# Out:
# ['c@web.de', 'felo@wichtig.de', 'infomachtspaß@nicht.de']

# %%
adressen[:2]
# Out:
# ['a@gmx.de', 'b@hotmail.de']

# %%
adressen[:]
# Out:
# ['a@gmx.de',
#  'b@hotmail.de',
#  'c@web.de',
#  'felo@wichtig.de',
#  'infomachtspaß@nicht.de']

# %%
adressen[::2]
# Out:
# ['a@gmx.de', 'c@web.de', 'infomachtspaß@nicht.de']

# %%
adressen[2::3]
# Out:
# ['c@web.de']

# %%
adressen[1:6:2]
# Out:
# ['b@hotmail.de', 'felo@wichtig.de']
